# %%
#To perform NER using spacy on user input text
import spacy
nlp = spacy.load('en_core_web_sm')
text = input("Enter the text: ")
doc = nlp(text)
for ent in doc.ents:
    print(
        f"""
    {ent.text = }
    {ent.start_char = }
    {ent.end_char = }
    {ent.label_ = }
    spacy.explain('{ent.label_}') = {spacy.explain(ent.label_)}"""
    )
# Out:
#     ent.text = 'Jeff Bezos'
#     ent.start_char = 0
#     ent.end_char = 10
#     ent.label_ = 'PERSON'
#     spacy.explain('PERSON') = People, including fictional
#
#     ent.text = 'Amazon'
#     ent.start_char = 19
#     ent.end_char = 25
#     ent.label_ = 'ORG'
#     spacy.explain('ORG') = Companies, agencies, institutions, etc.
#
#     ent.text = 'Seattle'
#     ent.start_char = 43
#     ent.end_char = 50
#     ent.label_ = 'GPE'
#     spacy.explain('GPE') = Countries, cities, states
#
#     ent.text = 'Apple'
#     ent.start_char = 52
#     ent.end_char = 57
#     ent.label_ = 'ORG'
#     spacy.explain('ORG') = Companies, agencies, institutions, etc.
#
#     ent.text = 'San Jose'
#     ent.start_char = 104
#     ent.end_char = 112
#     ent.label_ = 'GPE'
#     spacy.explain('GPE') = Countries, cities, states
#
#     ent.text = 'next June'
#     ent.start_char = 113
#     ent.end_char = 122
#     ent.label_ = 'DATE'
#     spacy.explain('DATE') = Absolute or relative dates or periods
#
#     ent.text = 'The Great Wall of China'
#     ent.start_char = 124
#     ent.end_char = 147
#     ent.label_ = 'FAC'
#     spacy.explain('FAC') = Buildings, airports, highways, bridges, etc.
#
#     ent.text = 'Asia'
#     ent.start_char = 188
#     ent.end_char = 192
#     ent.label_ = 'LOC'
#     spacy.explain('LOC') = Non-GPE locations, mountain ranges, bodies of water
#
#     ent.text = 'Tesla'
#     ent.start_char = 194
#     ent.end_char = 199
#     ent.label_ = 'ORG'
#     spacy.explain('ORG') = Companies, agencies, institutions, etc.
#
#     ent.text = 'Gigafactory'
#     ent.start_char = 213
#     ent.end_char = 224
#     ent.label_ = 'FAC'
#     spacy.explain('FAC') = Buildings, airports, highways, bridges, etc.
#
#     ent.text = 'Berlin'
#     ent.start_char = 228
#     ent.end_char = 234
#     ent.label_ = 'GPE'
#     spacy.explain('GPE') = Countries, cities, states
#
#     ent.text = 'last year'
#     ent.start_char = 235
#     ent.end_char = 244
#     ent.label_ = 'DATE'
#     spacy.explain('DATE') = Absolute or relative dates or periods
#
#     ent.text = 'Google'
#     ent.start_char = 246
#     ent.end_char = 252
#     ent.label_ = 'ORG'
#     spacy.explain('ORG') = Companies, agencies, institutions, etc.
#
#     ent.text = 'Mountain View'
#     ent.start_char = 287
#     ent.end_char = 300
#     ent.label_ = 'GPE'
#     spacy.explain('GPE') = Countries, cities, states
#
#     ent.text = 'California'
#     ent.start_char = 302
#     ent.end_char = 312
#     ent.label_ = 'GPE'
#     spacy.explain('GPE') = Countries, cities, states
#
#     ent.text = 'Nelson Mandela'
#     ent.start_char = 314
#     ent.end_char = 328
#     ent.label_ = 'PERSON'
#     spacy.explain('PERSON') = People, including fictional
#
#     ent.text = '27 years'
#     ent.start_char = 348
#     ent.end_char = 356
#     ent.label_ = 'DATE'
#     spacy.explain('DATE') = Absolute or relative dates or periods
#
#     ent.text = 'South Africa'
#     ent.start_char = 360
#     ent.end_char = 372
#     ent.label_ = 'GPE'
#     spacy.explain('GPE') = Countries, cities, states
#
#     ent.text = 'Olympics'
#     ent.start_char = 378
#     ent.end_char = 386
#     ent.label_ = 'EVENT'
#     spacy.explain('EVENT') = Named hurricanes, battles, wars, sports events, etc.
#
#     ent.text = 'Paris'
#     ent.start_char = 403
#     ent.end_char = 408
#     ent.label_ = 'GPE'
#     spacy.explain('GPE') = Countries, cities, states
#
#     ent.text = '2024'
#     ent.start_char = 412
#     ent.end_char = 416
#     ent.label_ = 'DATE'
#     spacy.explain('DATE') = Absolute or relative dates or periods
#
#     ent.text = 'Warren Buffett'
#     ent.start_char = 418
#     ent.end_char = 432
#     ent.label_ = 'PERSON'
#     spacy.explain('PERSON') = People, including fictional
#
#     ent.text = 'Hathaway'
#     ent.start_char = 448
#     ent.end_char = 456
#     ent.label_ = 'PERSON'
#     spacy.explain('PERSON') = People, including fictional
#
#     ent.text = 'Nile River'
#     ent.start_char = 492
#     ent.end_char = 502
#     ent.label_ = 'LOC'
#     spacy.explain('LOC') = Non-GPE locations, mountain ranges, bodies of water
#
#     ent.text = 'Egypt'
#     ent.start_char = 517
#     ent.end_char = 522
#     ent.label_ = 'GPE'
#     spacy.explain('GPE') = Countries, cities, states
#
#     ent.text = 'NASA'
#     ent.start_char = 564
#     ent.end_char = 568
#     ent.label_ = 'ORG'
#     spacy.explain('ORG') = Companies, agencies, institutions, etc.
#
#     ent.text = 'Mars'
#     ent.start_char = 597
#     ent.end_char = 601
#     ent.label_ = 'LOC'
#     spacy.explain('LOC') = Non-GPE locations, mountain ranges, bodies of water
#
#     ent.text = '2030'
#     ent.start_char = 605
#     ent.end_char = 609
#     ent.label_ = 'DATE'
#     spacy.explain('DATE') = Absolute or relative dates or periods

# %%
from spacy import displacy
displacy.serve(doc, style="ent")
# Out:
# <span class="tex2jax_ignore"><!DOCTYPE html>
# <html lang="en">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Jeff Bezos
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  founded
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Amazon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  in his garage in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Seattle
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# .
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is hosting its annual developer conference in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     San Jose
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     next June
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .
# <mark class="entity" style="background: #9cc9cc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The Great Wall of China
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FAC</span>
# </mark>
#  is one of the most visited landmarks in
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Asia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# .
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tesla
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  opened a new
# <mark class="entity" style="background: #9cc9cc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Gigafactory
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FAC</span>
# </mark>
#  in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Berlin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     last year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Google
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  has its largest campus located in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mountain View
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     California
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# .
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Nelson Mandela
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  was imprisoned for
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     27 years
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     South Africa
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# . The
# <mark class="entity" style="background: #ffeb80; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Olympics
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">EVENT</span>
# </mark>
#  will be held in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Paris
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2024
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Warren Buffett
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  runs Berkshire
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hathaway
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , a multinational conglomerate. The
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Nile River
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</s
# Using the 'ent' visualizer
# Serving on http://0.0.0.0:5000 ...
